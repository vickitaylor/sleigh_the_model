# %%
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit

# %%
data = pd.read_csv('../data/dataformodel.csv')

# %%
data.head(15)
# Out:
#           date    pce  inflation  unemployment_rate  revolving_credit  \
# 0   1959-01-01  306.1      29.01                6.0               NaN
# 1   1959-02-01  309.6      29.00                5.9               NaN
# 2   1959-03-01  312.7      28.97                5.6               NaN
# 3   1959-04-01  312.2      28.98                5.2               NaN
# 4   1959-05-01  316.1      29.04                5.1               NaN
# 5   1959-06-01  318.2      29.11                5.0               NaN
# 6   1959-07-01  317.8      29.15                5.1               NaN
# 7   1959-08-01  320.2      29.18                5.2               NaN
# 8   1959-09-01  324.2      29.25                5.5               NaN
# 9   1959-10-01  322.8      29.35                5.7               NaN
# 10  1959-11-01  322.9      29.35                5.8               NaN
# 11  1959-12-01  322.9      29.41                5.3               NaN
# 12  1960-01-01  323.6      29.37                5.2               NaN
# 13  1960-02-01  325.3      29.41                4.8               NaN
# 14  1960-03-01  330.2      29.41                5.4               NaN
#
#     nonrevolving_credit  total_credit
# 0              48961.16      48961.16
# 1              49513.71      49513.71
# 2              50007.73      50007.73
# 3              50463.43      50463.43
# 4              51007.24      51007.24
# 5              51675.44      51675.44
# 6              52356.85      52356.85
# 7              53038.53      53038.53
# 8              53683.75      53683.75
# 9              54365.95      54365.95
# 10             54794.81      54794.81
# 11             56010.68      56010.68
# 12             56015.58      56015.58
# 13             56364.63      56364.63
# 14             56862.88      56862.88

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 796 non-null    object
#  1   pce                  796 non-null    float64
#  2   inflation            796 non-null    float64
#  3   unemployment_rate    796 non-null    float64
#  4   revolving_credit     688 non-null    float64
#  5   nonrevolving_credit  796 non-null    float64
#  6   total_credit         796 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 43.7+ KB

# %%
# converting date to datetime format
data['date'] = pd.to_datetime(data['date'])

# %%
# variable to how many months in advance to predict 
months_in_adv = 3

# %%
# added column for future PCE values to make the target variable
data['pce_future'] = data['pce'].shift(-months_in_adv)

# %%
# filling in NaN values with 0 for revolving credit where there is no data for the first 10ish years 
data['revolving_credit'] = data['revolving_credit'].fillna(0)

# %%
features_to_lag = [
    'pce',
    'inflation',
    'unemployment_rate',
    'revolving_credit',
    'nonrevolving_credit',
    'total_credit'
]

# %%
# adding additional lag feature columns, using opposite shift and each month going back months_in_adv variable (so if set at 3, it will have 1, 2 ,3 months back)

def add_lag_features(df, months_lag, features):
    df_copy = df.copy()
    for feature in features:
        for i in range(1, months_lag + 1):
            df[f'{feature}_lag_{i}'] = df[feature].shift(i)
    return df_copy

# %%
data_with_lag = add_lag_features(data, months_in_adv, features_to_lag)

# %%
data_with_lag.head()
# Out:
#         date    pce  inflation  unemployment_rate  revolving_credit  \
# 0 1959-01-01  306.1      29.01                6.0               0.0
# 1 1959-02-01  309.6      29.00                5.9               0.0
# 2 1959-03-01  312.7      28.97                5.6               0.0
# 3 1959-04-01  312.2      28.98                5.2               0.0
# 4 1959-05-01  316.1      29.04                5.1               0.0
#
#    nonrevolving_credit  total_credit  pce_future  pce_lag_1  pce_lag_2  ...  \
# 0             48961.16      48961.16       312.2        NaN        NaN  ...
# 1             49513.71      49513.71       316.1      306.1        NaN  ...
# 2             50007.73      50007.73       318.2      309.6      306.1  ...
# 3             50463.43      50463.43       317.8      312.7      309.6  ...
# 4             51007.24      51007.24       320.2      312.2      312.7  ...
#
#    unemployment_rate_lag_3  revolving_credit_lag_1  revolving_credit_lag_2  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     0.0                     NaN
# 2                      NaN                     0.0                     0.0
# 3                      6.0                     0.0                     0.0
# 4                      5.9                     0.0                     0.0
#
#    revolving_credit_lag_3  nonrevolving_credit_lag_1  \
# 0                     NaN                        NaN
# 1                     NaN                   48961.16
# 2                     NaN                   49513.71
# 3                     0.0                   50007.73
# 4                     0.0                   50463.43
#
#    nonrevolving_credit_lag_2  nonrevolving_credit_lag_3  total_credit_lag_1  \
# 0                        NaN                        NaN                 NaN
# 1                        NaN                        NaN            48961.16
# 2                   48961.16                        NaN            49513.71
# 3                   49513.71                   48961.16            50007.73
# 4                   50007.73                   49513.71            50463.43
#
#    total_credit_lag_2  total_credit_lag_3
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2            48961.16                 NaN
# 3            49513.71            48961.16
# 4            50007.73            49513.71
#
# [5 rows x 26 columns]

# %%
# dropping rows with nan values (should be only first and last rows depending on the months_in_adv variable)
data_with_lag = data_with_lag.dropna()

# %%
data_with_lag.head()
# Out:
#         date    pce  inflation  unemployment_rate  revolving_credit  \
# 3 1959-04-01  312.2      28.98                5.2               0.0
# 4 1959-05-01  316.1      29.04                5.1               0.0
# 5 1959-06-01  318.2      29.11                5.0               0.0
# 6 1959-07-01  317.8      29.15                5.1               0.0
# 7 1959-08-01  320.2      29.18                5.2               0.0
#
#    nonrevolving_credit  total_credit  pce_future  pce_lag_1  pce_lag_2  ...  \
# 3             50463.43      50463.43       317.8      312.7      309.6  ...
# 4             51007.24      51007.24       320.2      312.2      312.7  ...
# 5             51675.44      51675.44       324.2      316.1      312.2  ...
# 6             52356.85      52356.85       322.8      318.2      316.1  ...
# 7             53038.53      53038.53       322.9      317.8      318.2  ...
#
#    unemployment_rate_lag_3  revolving_credit_lag_1  revolving_credit_lag_2  \
# 3                      6.0                     0.0                     0.0
# 4                      5.9                     0.0                     0.0
# 5                      5.6                     0.0                     0.0
# 6                      5.2                     0.0                     0.0
# 7                      5.1                     0.0                     0.0
#
#    revolving_credit_lag_3  nonrevolving_credit_lag_1  \
# 3                     0.0                   50007.73
# 4                     0.0                   50463.43
# 5                     0.0                   51007.24
# 6                     0.0                   51675.44
# 7                     0.0                   52356.85
#
#    nonrevolving_credit_lag_2  nonrevolving_credit_lag_3  total_credit_lag_1  \
# 3                   49513.71                   48961.16            50007.73
# 4                   50007.73                   49513.71            50463.43
# 5                   50463.43                   50007.73            51007.24
# 6                   51007.24                   50463.43            51675.44
# 7                   51675.44                   51007.24            52356.85
#
#    total_credit_lag_2  total_credit_lag_3
# 3            49513.71            48961.16
# 4            50007.73            49513.71
# 5            50463.43            50007.73
# 6            51007.24            50463.43
# 7            51675.44            51007.24
#
# [5 rows x 26 columns]

# %%
data_with_lag.tail()
# Out:
#           date      pce  inflation  unemployment_rate  revolving_credit  \
# 788 2024-09-01  20044.1    314.851                4.1        1360370.46
# 789 2024-10-01  20123.2    315.564                4.1        1369397.34
# 790 2024-11-01  20235.1    316.449                4.2        1358585.49
# 791 2024-12-01  20408.1    317.603                4.1        1316865.89
# 792 2025-01-01  20389.0    319.086                4.0        1323514.25
#
#      nonrevolving_credit  total_credit  pce_future  pce_lag_1  pce_lag_2  ...  \
# 788           3733724.31    5094094.77     20408.1    19905.0    19866.3  ...
# 789           3735086.52    5104483.86     20389.0    20044.1    19905.0  ...
# 790           3739805.47    5098390.96     20469.3    20123.2    20044.1  ...
# 791           3671015.14    4987881.03     20621.8    20235.1    20123.2  ...
# 792           3673358.72    4996872.97     20669.5    20408.1    20235.1  ...
#
#      unemployment_rate_lag_3  revolving_credit_lag_1  revolving_credit_lag_2  \
# 788                      4.1              1357981.88              1357350.28
# 789                      4.2              1360370.46              1357981.88
# 790                      4.2              1369397.34              1360370.46
# 791                      4.1              1358585.49              1369397.34
# 792                      4.1              1316865.89              1358585.49
#
#      revolving_credit_lag_3  nonrevolving_credit_lag_1  \
# 788              1349803.77                 3731895.86
# 789              1357350.28                 3733724.31
# 790              1357981.88                 3735086.52
# 791              1360370.46                 3739805.47
# 792              1369397.34                 3671015.14
#
#      nonrevolving_credit_lag_2  nonrevolving_credit_lag_3  total_credit_lag_1  \
# 788                 3724143.76                 3713982.90          5089877.75
# 789                 3731895.86                 3724143.76          5094094.77
# 790                 3733724.31                 3731895.86          5104483.86
# 791                 3735086.52                 3733724.31          5098390.96
# 792                 3739805.47                 3735086.52          4987881.03
#
#      total_credit_lag_2  total_credit_lag_3
# 788          5081494.04          5063786.67
# 789          5089877.75          5081494.04
# 790          5094094.77          5089877.75
# 791          5104483.86          5094094.77
# 792          5098390.96          5104483.86
#
# [5 rows x 26 columns]

# %%
X = data.drop(columns=['pce_future'])
y = data['pce_future']
